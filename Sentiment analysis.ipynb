# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
from nltk.corpus import stopwords
from nltk.tag import pos_tag, StanfordNERTagger
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
import pandas as pd

#def read_csv_file(filename, positive_column, negative_column):
    #df = pd.read_csv(filename)
    #positive_words = df[positive_column].tolist()
    #negative_words = df[negative_column].tolist()

    #return positive_words, negative_words

# Example usage
#filename = 'wordlist\\Positive_Negative_Word.csv'  # Replace with your CSV file path
#positive_column = 'Positive_Word'
#negative_column = 'Negative_Word'

#positive_words, negative_words = read_csv_file(filename, positive_column, negative_column)

# Print the extracted words
#positive_wordss = [item for item in positive_words if not isinstance(item, float)]
#print("Positive words:", positive_words)
#print("Negative words:", negative_words)

positive_words = ["well", "good", "great", "like", "better", "enough", "happy", "love", "pleasure", "happiness"]
negative_words = ["miss", "poor", "doubt", "object", "sorry", "impossible", "afraid", "scarcely", "bad", "anxious"]

# %%
file = open("Coffee.txt")
text = file.read()

words = nltk.word_tokenize(text)
positive_score = 0
negative_score = 0

for word in words:
    if word in positive_words:
        positive_score += 1
    elif word in negative_words:
        negative_score += 1

if positive_score > negative_score:
    print("The text is positive")
else:
    print("The text is negative")
    
print(positive_score)
print(negative_score)
# Out:
# The text is positive
# 2
# 0

# %%
stop_words=stopwords.words("english")
#print(len(stop_words))

filtered_words = []

for word in words:
    if word not in stop_words:
        filtered_words.append(word)
        
        
        filtered_list = [item for item in filtered_words if not isinstance(item, float)]

print(filtered_list)
# Out:
# ['Crisply', 'sweet', ',', 'cocoa-toned', '.', 'Lemon', 'blossom', ',', 'roasted', 'cacao', 'nib', ',', 'date', ',', 'rice', 'candy', ',', 'white', 'peppercorn', 'aroma', 'cup', '.', 'Savory-tart', 'structure', ';', 'delicate', ',', 'silky', 'mouthfeel', '.', 'The', 'richly', 'drying', 'finish', 'leads', 'cocoa-toned', ',', 'crisply', 'sweet', 'floral', 'notes', 'short', 'hint', 'spice', '(', 'white', 'peppercorn', ')', 'long', '.', 'Delicate', ',', 'sweetly', 'spice-toned', '.', 'Pink', 'peppercorn', ',', 'date', ',', 'myrrh', ',', 'lavender', ',', 'roasted', 'cacao', 'nib', 'aroma', 'cup', '.', 'Crisp', ',', 'spice-toned', 'structure', 'citrus-like', 'acidity', ';', 'satiny', ',', 'smooth', 'mouthfeel', '.', 'The', 'crisply', 'sweet', 'finish', 'centers', 'around', 'spice', 'pungent', 'floral', 'notes', '.', 'Deeply', 'sweet', ',', 'subtly', 'pungent', '.', 'Honey', ',', 'pear', ',', 'tangerine', 'zest', ',', 'dark', 'chocolate', ',', 'pistachio', 'aroma', 'cup', '.', 'Sweet', 'juicy', 'yet', 'crisp', 'structure', '(', 'think', 'ripe', 'pear', ')', ';', 'plush', 'buoyant', 'mouthfeel', '.', 'Resonant', 'flavor', 'saturated', 'short', 'finish', ';', 'simplifies', 'around', 'hints', 'tangerine', 'pistachio', 'long', '.', 'Delicate', ',', 'richly', 'sweetly', 'tart', '.', 'Dried', 'hibiscus', ',', 'fine', 'musk', ',', 'almond', ',', 'sandalwood', ',', 'raspberry', 'aroma', 'cup', '.', 'Fruit-toned', ',', 'deeply', 'sweet', 'structure', 'gently-expressed', 'acidity', ';', 'buoyant', ',', 'satiny-smooth', 'mouthfeel', '.', 'The', 'crisp', ',', 'flavor-saturated', 'finish', 'characterized', 'sweet-tart', 'fruit', 'floral', 'tones', '(', 'raspberry', ',', 'hibiscus', ')', '.', 'High-toned', ',', 'floral', '.', 'Dried', 'apricot', ',', 'magnolia', ',', 'almond', 'butter', ',', 'maple', 'syrup', ',', 'cherry', 'brandy', 'aroma', 'cup', '.', 'Crisp', ',', 'sweetly-tart', 'structure', ';', 'plush', ',', 'syrupy', 'mouthfeel', '.', 'Notes', 'magnolia', 'dried', 'apricot', 'dominate', 'flavor-laden', 'short', 'finish', ',', 'hints', 'almond', 'butter', 'fruit', 'brandy', 'long', '.', 'Very', 'delicate', ',', 'sweetly', 'savory', '.', 'Lemon', 'verbena', ',', 'allspice', ',', 'dried', 'persimmon', ',', 'dogwood', ',', 'bakerÃ¢â‚¬â', '„', '¢s', 'chocolate', 'aroma', 'cup', '.', 'Balanced', ',', 'sweet-savory', 'structure', ';', 'velvety-smooth', 'mouthfeel', '.', 'The', 'sweetly', 'herb-toned', 'finish', 'centers', 'notes', 'lemon', 'verbena', 'dried', 'persimmon', 'wrapped', 'bakerÃ¢â‚¬â', '„', '¢s', 'chocolate', '.', 'High-toned', ',', 'crisply', 'sweet', '.', 'Lemon', 'blossom', ',', 'apricot', ',', 'frankincense', ',', 'spearmint', ',', 'roasted', 'cacao', 'nib', 'aroma', 'cup', '.', 'Balanced', ',', 'complete', 'sweet-savory', 'structure', ';', 'satiny', ',', 'full', 'mouthfeel', '.', 'Sweet', 'spearmint', 'notes', 'carry', 'cocoa-toned', 'finish', ',', 'hints', 'lemon', 'blossom', 'apricot', '.', 'Balanced', ',', 'sweet-savory', '.', 'Red', 'currant', ',', 'roasted', 'cacao', 'nib', ',', 'clove', ',', 'blood', 'orange', 'zest', ',', 'frankincense', 'aroma', 'cup', '.', 'Savory-sweet', 'structure', 'lively', 'acidity', ';', 'syrupy', 'mouthfeel', '.', 'The', 'resonant', ',', 'spice-toned', 'finish', 'leads', 'intimations', 'clove', 'roasted', 'cacao', 'nib', 'short', ',', 'rounding', 'rich', 'fruit', 'tones', 'hints', 'frankincense', 'long', '.', 'Surprising', 'melodic', ',', 'delicate', 'yet', 'vivid', '.', 'Lilac', 'lemon', 'blossom', ',', 'fresh', 'sweet', 'grass', ',', 'honey', ',', 'moist', 'pipe', 'tobacco', ',', 'fresh-cut', 'elm', 'aroma', 'cup', '.', 'In', 'structure', 'subtly', 'sweetly', 'tart', '.', 'Very', 'light', ',', 'silky', 'mouthfeel', '.', 'Unexpectedly', 'rich', 'flavor-saturated', 'finish', ':', 'pipe', 'tobacco', ',', 'honey', ',', 'lemon', 'blossom', '.', 'Delicate', ',', 'gently', 'tart', ',', 'spice-toned', '.', 'Pomegranate', ',', 'cocoa', 'powder', ',', 'lemon', 'blossom', ',', 'white', 'peppercorn', ',', 'h ...

# %%
from nltk.corpus import wordnet

positive_score = 0
negative_score = 0
positive_similarity = []
negative_similarity = []

for word in filtered_words:
    for positive_word in positive_words:
        if(wordnet.synsets(word) and wordnet.synsets(positive_word)):
            word1 = wordnet.synsets(word)[0]
            word2 = wordnet.synsets(positive_word)[0]
            positive_similarity.append(word1.wup_similarity(word2))
            positive_similarity = list(filter(None, positive_similarity)) 
    for negative_word in negative_words:
        if(wordnet.synsets(word) and wordnet.synsets(negative_word)):
            word1 = wordnet.synsets(word)[0]
            word2 = wordnet.synsets(negative_word)[0]
            negative_similarity.append(word1.wup_similarity(word2))
            negative_similarity = list(filter(None, negative_similarity)) 
    if positive_similarity:
        positive_score += max(positive_similarity)
    if negative_similarity:
        negative_score += max(negative_similarity)
    positive_similarity = []
    negative_similarity = []

if positive_score > negative_score:
    print("The text is positive")
else:
    print("The text is negative")
